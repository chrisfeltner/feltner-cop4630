# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisfeltner/feltner-cop4630/blob/master/HW1/HomeworkOneProblemThreeChristopherFeltner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework One - Problem Three
# ### Christopher Feltner

# %%
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

(trainImages, trainLabels), (testImages, testLabels) = mnist.load_data()

sortedNumbers = [[], [], [], [], [], [], [], [], [], []]
avgs = [np.zeros_like(trainImages[0])] * 10

for i in range(len(trainImages)):
  sortedNumbers[trainLabels[i]].append(trainImages[i])

for i in range(len(testImages)):
  sortedNumbers[testLabels[i]].append(testImages[i])

plt.figure(figsize=(4, 4))

for i in range(len(sortedNumbers)):
  avgs[i] = np.mean(sortedNumbers[i], axis=0)
  plt.imshow(avgs[i])
  plt.show()
